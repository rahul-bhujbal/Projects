# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul-bhujbal/Projects/blob/google-colab/3.Python_if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# If-else in python

# %%
# login programe and indentation
# email -> rahul.bhujbal369@gmail.com
# password -> 123

email = input('Enter your email')
password = input('Enter Your Password')

if email == 'rahul.bhujbal369@gmail.com' and password == '123':
  print('Welcome',email)
else:
  print('Wrong email or password, Please try again')
# Out:
# Enter your emailrahul.bhujbal369@gmail.com
# Enter Your Password1234
# Wrong email or password, Please try again

# %%
email = input('Enter your email')
password = input('Enter Your Password')

if email == 'rahul.bhujbal369@gmail.com' and password == '123':
  print('Welcome',email)
elif email == 'rahul.bhujbal369@gmail.com' and password != '123':
  print('Incorrect Password')
  password = input('Enter Your Password again')
  if password == '123':
    print('Welcome',email)
  else:
    print('Your attempt is over, Please check with your admin')
else:
  print('Wrong inputs')
# Out:
# Enter your emailrahul.bhujbal369@gmail.com
# Enter Your Password123
# Welcome rahul.bhujbal369@gmail.com

# %%
# 1. Find the min of 3 given no
a = int(input('Enter your first no'))
b = int(input('Enter your second no'))
c = int(input('Enter your third no'))

if a<b and a<c:
  print('Smallest no is: ', a)
elif b<c:
  print('Smallest no is: ', b)
else:
  print('Smallest no is: ', c)
# Out:
# Enter your first no12
# Enter your second no12
# Enter your third no12
# Smallest no is:  12

# %%
# Menu driven calculator

fnum = int(input('Enter first number: '))
snum = int(input('Enter second number: '))

operation =  input('Enter operation')

if operation == '+':
  print(fnum+snum)
elif operation == '-':
  print(fnum-snum)
elif operation == '*':
  print(fnum*snum)
else:
  print(fnum/snum)
# Out:
# Enter first number: 10
# Enter second number: 20
# Enter operationk
# 0.5

# %%
# Menu driven ATM
menu = input("""
Hi ! How can i help you!!!
1. Enter 1 for pin change
2. Enter 2 for balance check
3. Enter 3 for Withdraw
4. Enter any thing except 1,2,3 for exit
""")

if menu == '1':
  print('Pin chnage')
elif menu == '2':
  print('Balance')
elif menu == '3':
  print('Please collect you cash')
else:
  print('Exit')
# Out:
# Hi ! How can i help you!!!
# 1. Enter 1 for pin change
# 2. Enter 2 for balance check
# 3. Enter 3 for Withdraw
# 4. Enter any thing except 1,2,3 for exit
# 7
# Exit

# %% [markdown]
# Modules in python
#
#
# *   math
# *   keywords
#
#
# *   random
# *   datetime

# %%
# math
import math
math.factorial(5)
math.floor(6.8)
math.sqrt(196)
# Out:
# 14.0

# %%
# Keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# random
import random
print(random.randint(1,6))
# Out:
# 3

# %%
# datetime
import datetime
print(datetime.datetime.now())
# Out:
# 2026-09-12 05:18:59.125379
